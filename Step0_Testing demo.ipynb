# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pathlib

print(os.getcwd())

path = "/content/drive/MyDrive/PhD_Research/SAM/Polygonal_Mapping"
os.chdir(path)

print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/PhD_Research/SAM/Polygonal_Mapping

# %% [markdown]
# ## 1. Copy the inria_to_coco.py

# %%
# !pip install -q imagecodecs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 39.7 MB/s eta 0:00:00

# %%
# Transform Inria gt dataset (binary image) to COCO format
# Using cv2.findcontours and polygon simplify to convert raster label to vector label
#
# The first 5 images are kept as validation set

from pycocotools.coco import COCO
import os
import numpy as np
from skimage import io
import json
from tqdm import tqdm
from itertools import groupby
from shapely.geometry import Polygon, mapping
from skimage.measure import label as ski_label
from skimage.measure import regionprops
from shapely.geometry import box
import cv2
import glob
import math
import imagecodecs

def polygon2hbb(poly):
    """
    Get horizontal bounding box (match COCO)
    """
    p_x = poly[:, 0]
    p_y = poly[:, 1]
    hbb_x = np.min(p_x)
    hbb_y = np.min(p_y)
    hbb_w = np.around(np.max(p_x) - hbb_x, decimals=2)
    hbb_h = np.around(np.max(p_y) - hbb_y, decimals=2)
    hbox = [hbb_x, hbb_y, hbb_w, hbb_h]
    return [float(i) for i in hbox]

def clip_by_bound(poly, im_h, im_w):
    """
    Bound poly coordinates by image shape
    """
    p_x = poly[:, 0]
    p_y = poly[:, 1]
    p_x = np.clip(p_x, 0.0, im_w-1)
    p_y = np.clip(p_y, 0.0, im_h-1)
    return np.concatenate((p_x[:, np.newaxis], p_y[:, np.newaxis]), axis=1)

def crop2patch(im_p, p_h, p_w, p_overlap):
    """
    Get coordinates of upper-left point for image patch
    return: patch_list [X_upper-left, Y_upper-left, patch_width, patch_height]
    """
    im_h, im_w, _ = im_p
    x = np.arange(0, im_w-p_w, p_w-p_overlap)
    x = np.append(x, im_w-p_w)
    y = np.arange(0, im_h-p_h, p_h-p_overlap)
    y = np.append(y, im_h-p_h)
    X, Y = np.meshgrid(x, y)
    patch_list = [[i, j, p_w, p_h] for i, j in zip(X.flatten(), Y.flatten())]
    return patch_list

def polygon_in_bounding_box(polygon, bounding_box):
    """
    Returns True if all vertices of polygons are inside bounding_box
    :param polygon: [N, 2]
    :param bounding_box: [row_min, col_min, row_max, col_max]
    :return:
    """
    result = np.all(
        np.logical_and(
            np.logical_and(bounding_box[0] <= polygon[:, 0], polygon[:, 0] <= bounding_box[0] + bounding_box[2]),
            np.logical_and(bounding_box[1] <= polygon[:, 1], polygon[:, 1] <= bounding_box[1] + bounding_box[3])
        )
    )
    return result

def transform_poly_to_bounding_box(polygon, bounding_box):
    """
    Transform the original coordinates of polygon to bbox
    :param polygon: [N, 2]
    :param bounding_box: [row_min, col_min, row_max, col_max]
    :return:
    """
    transformed_polygon = polygon.copy()
    transformed_polygon[:, 0] -= bounding_box[0]
    transformed_polygon[:, 1] -= bounding_box[1]
    return transformed_polygon

def bmask_to_poly(b_im, simplify_ind, tolerance=1.8, ):
    """
    Convert binary mask to polygons
    """
    polygons = []
    # pad mask to close contours of shapes which start and end at an edge
    try:
        label_img = ski_label(b_im > 0)
    except:
        print('error')
    props = regionprops(label_img)
    for prop in props:
        prop_mask = np.zeros_like(b_im)
        prop_mask[prop.coords[:, 0], prop.coords[:, 1]] = 1
        padded_binary_mask = np.pad(prop_mask, pad_width=1, mode='constant', constant_values=0)
        contours, hierarchy = cv2.findContours(padded_binary_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) > 1:
            intp = []
            for contour, h in zip(contours, hierarchy[0]):
                contour = np.array([c.reshape(-1).tolist() for c in contour])
                # subtract pad
                contour -= 1
                contour = clip_by_bound(contour, b_im.shape[0], b_im.shape[1])
                if len(contour) > 3:
                    closed_c = np.concatenate((contour, contour[0].reshape(-1, 2)))
                    if h[3] < 0:
                        extp = [tuple(i) for i in closed_c]
                    else:
                        if cv2.contourArea(closed_c.astype(int)) > 10:
                            intp.append([tuple(i) for i in closed_c])
            poly = Polygon(extp, intp)
            if simplify_ind:
                poly = poly.simplify(tolerance=tolerance, preserve_topology=False)
                if isinstance(poly, Polygon):
                    polygons.append(poly)
                else:
                    for idx in range(len(poly.geoms)):
                        polygons.append(poly.geoms[idx])
        elif len(contours) == 1:
            contour = np.array([c.reshape(-1).tolist() for c in contours[0]])
            contour -= 1
            contour = clip_by_bound(contour, b_im.shape[0], b_im.shape[1])
            if len(contour) > 3:
                closed_c = np.concatenate((contour, contour[0].reshape(-1, 2)))
                poly = Polygon(closed_c)

            # simply polygon vertex
                if simplify_ind:
                    poly = poly.simplify(tolerance=tolerance, preserve_topology=False)
                if isinstance(poly, Polygon):
                    polygons.append(poly)
                else:
                    for idx in range(len(poly.geoms)):
                        polygons.append(poly.geoms[idx])
            # print(np.array(poly.exterior.coords).ravel().tolist())
            # in case that after "simplify", one polygon turn to multiply polygons
            # (pixels in polygon) are not connected
    return polygons

def rotate_image(image, angle):
    """
    Rotates an OpenCV 2 / NumPy image about it's centre by the given angle
    (in degrees). The returned image will be large enough to hold the entire
    new image, with a black background
    """

    # Get the image size
    # No that's not an error - NumPy stores image matricies backwards
    image_size = (image.shape[1], image.shape[0])
    image_center = tuple(np.array(image_size) / 2)

    # Convert the OpenCV 3x2 rotation matrix to 3x3
    rot_mat = np.vstack(
        [cv2.getRotationMatrix2D(image_center, angle, 1.0), [0, 0, 1]]
    )

    rot_mat_notranslate = np.matrix(rot_mat[0:2, 0:2])

    # Shorthand for below calcs
    image_w2 = image_size[0] * 0.5
    image_h2 = image_size[1] * 0.5

    # Obtain the rotated coordinates of the image corners
    rotated_coords = [
        (np.array([-image_w2,  image_h2]) * rot_mat_notranslate).A[0],
        (np.array([ image_w2,  image_h2]) * rot_mat_notranslate).A[0],
        (np.array([-image_w2, -image_h2]) * rot_mat_notranslate).A[0],
        (np.array([ image_w2, -image_h2]) * rot_mat_notranslate).A[0]
    ]

    # Find the size of the new image
    x_coords = [pt[0] for pt in rotated_coords]
    x_pos = [x for x in x_coords if x > 0]
    x_neg = [x for x in x_coords if x < 0]

    y_coords = [pt[1] for pt in rotated_coords]
    y_pos = [y for y in y_coords if y > 0]
    y_neg = [y for y in y_coords if y < 0]

    right_bound = max(x_pos)
    left_bound = min(x_neg)
    top_bound = max(y_pos)
    bot_bound = min(y_neg)

    new_w = int(abs(right_bound - left_bound))
    new_h = int(abs(top_bound - bot_bound))

    # We require a translation matrix to keep the image centred
    trans_mat = np.matrix([
        [1, 0, int(new_w * 0.5 - image_w2)],
        [0, 1, int(new_h * 0.5 - image_h2)],
        [0, 0, 1]
    ])

    # Compute the tranform for the combined rotation and translation
    affine_mat = (np.matrix(trans_mat) * np.matrix(rot_mat))[0:2, :]

    # Apply the transform
    result = cv2.warpAffine(
        image,
        affine_mat,
        (new_w, new_h),
        flags=cv2.INTER_LINEAR
    )

    return result

def largest_rotated_rect(w, h, angle):
    """
    Given a rectangle of size wxh that has been rotated by 'angle' (in
    radians), computes the width and height of the largest possible
    axis-aligned rectangle within the rotated rectangle.

    Original JS code by 'Andri' and Magnus Hoff from Stack Overflow

    Converted to Python by Aaron Snoswell
    """

    quadrant = int(math.floor(angle / (math.pi / 2))) & 3
    sign_alpha = angle if ((quadrant & 1) == 0) else math.pi - angle
    alpha = (sign_alpha % math.pi + math.pi) % math.pi

    bb_w = w * math.cos(alpha) + h * math.sin(alpha)
    bb_h = w * math.sin(alpha) + h * math.cos(alpha)

    gamma = math.atan2(bb_w, bb_w) if (w < h) else math.atan2(bb_w, bb_w)

    delta = math.pi - alpha - gamma

    length = h if (w < h) else w

    d = length * math.cos(alpha)
    a = d * math.sin(alpha) / math.sin(delta)

    y = a * math.cos(gamma)
    x = y * math.tan(gamma)

    return (
        bb_w - 2 * x,
        bb_h - 2 * y
    )

def crop_around_center(image, width, height):
    """
    Given a NumPy / OpenCV 2 image, crops it to the given width and height,
    around it's centre point
    """

    image_size = (image.shape[1], image.shape[0])
    image_center = (int(image_size[0] * 0.5), int(image_size[1] * 0.5))

    if(width > image_size[0]):
        width = image_size[0]

    if(height > image_size[1]):
        height = image_size[1]

    x1 = int(image_center[0] - width * 0.5)
    x2 = int(image_center[0] + width * 0.5)
    y1 = int(image_center[1] - height * 0.5)
    y2 = int(image_center[1] + height * 0.5)

    return image[y1:y2, x1:x2]

def rotate_crop(im, gt, crop_size, angle):
    h, w = im.shape[0:2]
    im_rotated = rotate_image(im, angle)
    gt_rotated = rotate_image(gt, angle)
    if largest_rotated_rect(w, h, math.radians(angle))[0] > crop_size:
        im_cropped = crop_around_center(im_rotated, crop_size, crop_size)
        gt_cropped = crop_around_center(gt_rotated, crop_size, crop_size)
    else:
        print('error')
        im_cropped = crop_around_center(im, crop_size, crop_size)
        gt_cropped = crop_around_center(gt, crop_size, crop_size)
    return im_cropped, gt_cropped

def lt_crop(im, gt, crop_size):
    im_cropped = im[0:crop_size, 0:crop_size, :]
    gt_cropped = gt[0:crop_size, 0:crop_size]
    return im_cropped, gt_cropped

def affine_transform(pt, t):
    new_pt = np.array([pt[0], pt[1], 1.], dtype=np.float32).T
    new_pt = np.dot(t, new_pt)
    return new_pt[:2]

# %%
def convert_to_coco(path_dataset):

    input_image_path = path_dataset + '/raw/train/images/'
    input_gt_path = path_dataset + '/raw/train/gt/'
    save_path = path_dataset + '/train/'

    cities = [city]
    val_set = [] #[str(i) for i in range(1, 6)]

    output_im_train = os.path.join(save_path, 'images')
    if not os.path.exists(output_im_train):
        os.makedirs(output_im_train)

    patch_width = 725
    patch_height = 725
    patch_overlap = 300
    patch_size = 512
    rotation_list = [22.5, 67.5]

    # main dict for annotation file
    output_data_train = {
        'info': {'district': city, 'description': 'building footprints', 'contributor': 'YG'},
        'categories': [{'id': 1, 'name': 'building'}],
        'images': [],
        'annotations': [],
    }

    train_ob_id = 0
    train_im_id = 0
    # read in data with npy format
    input_label = os.listdir(input_gt_path)
    for g_id, label in enumerate(tqdm(input_label)):
        # read data
        label_info = [''.join(list(g)) for k, g in groupby(label, key=lambda x: x.isdigit())]
        label_name = label_info[0] + label_info[1]
        image_data = io.imread(os.path.join(input_image_path, label_name + '.tif'))
        gt_im_data = io.imread(os.path.join(input_gt_path, label_name + '.tif'))
        im_h, im_w, _ = image_data.shape

        if label_info[1] not in val_set and label_info[0] in cities:
            # for training set, split image to 512x512
            patch_list = crop2patch(image_data.shape, patch_width, patch_height, patch_overlap)
            for pid, pa in enumerate(patch_list):
                x_ul, y_ul, pw, ph = pa

                p_gt = gt_im_data[y_ul:y_ul+patch_height, x_ul:x_ul+patch_width]
                p_im = image_data[y_ul:y_ul+patch_height, x_ul:x_ul+patch_width, :]
                p_gts = []
                p_ims = []
                p_im_rd, p_gt_rd = lt_crop(p_im, p_gt, patch_size)
                p_gts.append(p_gt_rd)
                p_ims.append(p_im_rd)
                for angle in rotation_list:
                    rot_im, rot_gt = rotate_crop(p_im, p_gt, patch_size, angle)
                    p_gts.append(rot_gt)
                    p_ims.append(rot_im)
                for p_im, p_gt in zip(p_ims, p_gts):
                    p_gt = p_gt.astype('uint8')
                    if np.sum(p_gt > 0) > 5:
                        p_polygons = bmask_to_poly(p_gt, 1)
                        for poly in p_polygons:
                            p_area = round(poly.area, 2)
                            if p_area > 0:
                                p_bbox = [poly.bounds[0], poly.bounds[1],
                                          poly.bounds[2]-poly.bounds[0], poly.bounds[3]-poly.bounds[1]]
                                if p_bbox[2] > 5 and p_bbox[3] > 5:
                                    p_seg = []
                                    coor_list = mapping(poly)['coordinates']
                                    for part_poly in coor_list:
                                        p_seg.append(np.asarray(part_poly).ravel().tolist())
                                    anno_info = {
                                        'id': train_ob_id,
                                        'image_id': train_im_id,
                                        'segmentation': p_seg,
                                        'area': p_area,
                                        'bbox': p_bbox,
                                        'category_id': 100,
                                        'iscrowd': 0
                                    }
                                    output_data_train['annotations'].append(anno_info)
                                    train_ob_id += 1
                    # get patch info
                    p_name = label_name + '-' + str(train_im_id) + '.tif'
                    patch_info = {'id': train_im_id, 'file_name': p_name, 'width': patch_size, 'height': patch_size}
                    output_data_train['images'].append(patch_info)
                    # save patch image
                    io.imsave(os.path.join(output_im_train, p_name), p_im)
                    train_im_id += 1

    if not os.path.exists(save_path):
        os.makedirs(save_path)
    with open(os.path.join(save_path, 'annotation.json'), 'w') as f_json:
        json.dump(output_data_train, f_json)

# %%
# print all datasets
path_database = "./Data"
os.listdir(path_database)
# Out:
# ['BFA_Djibo_20191212',
#  'BGD_Kutupalong_20180213',
#  'BGD_Kutupalong_20171224',
#  'CMR_Minawao_20170212',
#  'ETH_KuleTierkidi_20180622',
#  'ETH_Nguenygiel_20170324',
#  'ETH_Nguenygiel_20180622',
#  'KEN_Dagahaley_20170408',
#  'TZA_Nduta_20170813',
#  'ETH_KuleTierkidi_20170324']

# %%
dataset = "BGD_Kutupalong_20171224"
city = 'kutupalong2017'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# 100%|██████████| 7/7 [00:47<00:00,  6.84s/it]

# %%
dataset = "CMR_Minawao_20170212"
city = 'minawao'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]<ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-7.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-8.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-9.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-10.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-11.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-12.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-13.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-14.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-15.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-16.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-17.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-18.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-19.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-20.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-21.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-22.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-23.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-24.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-25.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-26.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-27.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-28.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-29.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-30.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-31.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-32.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-33.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-34.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-35.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-36.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-37.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-38.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-39.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-40.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-41.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-42.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-43.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-44.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-45.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-46.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-48.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-49.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-50.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-51.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-52.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-53.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-55.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-56.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-59.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-62.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-63.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-64.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-65.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-66.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-67.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-68.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-69.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-70.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-71.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-73.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-74.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-75.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-76.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-77.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-78.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-79.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-80.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-82.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-83.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-84.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-85.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-86.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-88.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-89.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-90.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-91.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-92.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-93.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-94.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-95.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-96.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-97.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-98.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-99.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-100.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-101.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-102.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-103.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-104.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-105.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-106.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-107.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-112.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-113.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-114.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-115.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-116.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-120.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-121.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-122.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-123.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-124.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-125.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-126.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-127.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-128.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-129.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-130.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-131.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-132.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-133.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-134.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-136.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-137.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-138.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-139.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-140.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-141.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-142.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-143.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-144.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-145.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-146.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-147.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-148.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-149.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-150.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-151.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-152.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-153.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-154.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-155.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-156.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-157.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-158.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-159.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-160.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-161.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-162.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-163.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-164.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-165.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-166.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-167.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-168.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-169.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-170.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-171.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-172.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-173.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-174.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-175.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-176.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-177.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-178.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-179.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-180.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-181.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-182.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-183.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-184.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-185.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-186.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-187.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-188.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-189.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-190.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-191.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-198.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-199.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-200.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-201.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-202.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-203.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-204.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-205.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-206.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-207.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-208.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-209.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-210.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-211.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-212.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-213.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-214.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-215.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-216.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-217.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-218.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-223.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-224.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-225.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-226.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-227.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-228.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-229.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-230.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-231.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-232.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-233.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-234.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-235.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-236.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-237.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-238.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-239.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-240.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-241.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-242.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-243.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-244.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-245.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-246.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-247.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-248.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-249.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-250.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-251.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-252.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-253.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-254.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-255.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-256.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-257.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-258.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-259.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-260.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-262.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-263.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-264.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-265.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-266.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-267.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-268.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-269.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-270.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-271.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-272.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-273.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-274.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-275.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-276.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-277.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-278.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-279.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-280.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-281.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-282.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-283.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-284.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-285.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-286.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-287.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# ...
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1989.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1990.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1991.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1992.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1993.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1994.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1995.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1996.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1997.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1998.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-1999.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2000.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2005.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2006.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2007.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2008.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2009.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2010.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2011.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2012.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2013.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2014.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2015.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2016.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2017.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2018.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2019.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2020.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2021.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2022.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2023.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2024.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2025.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2026.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2027.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2028.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2029.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2030.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2031.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2032.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2033.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2034.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2035.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2036.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2037.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2038.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2039.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2040.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2041.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2042.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2044.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2045.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2046.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2047.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2048.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2049.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2050.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2051.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2052.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2053.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2054.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2055.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2056.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2057.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2058.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2059.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2060.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2061.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2062.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2063.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2064.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2065.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2066.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2067.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2068.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2069.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2071.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2072.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2073.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2074.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2075.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2076.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2077.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-28-11110581e3ca>:87: UserWarning: ./Data/CMR_Minawao_20170212/train/images/minawao1-2078.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# 100%|██████████| 7/7 [05:18<00:00, 45.48s/it]

# %%
dataset = "ETH_KuleTierkidi_20170324"
city = 'kule2017'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# 100%|██████████| 6/6 [00:16<00:00,  2.82s/it]

# %%
dataset = "ETH_KuleTierkidi_20180622"
city = 'kule2018'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# 100%|██████████| 7/7 [00:15<00:00,  2.22s/it]

# %%
dataset = "ETH_Nguenygiel_20170324"
city = 'ngu2017'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# 100%|██████████| 7/7 [00:11<00:00,  1.60s/it]

# %%
dataset = "ETH_Nguenygiel_20180622"
city = 'ngu2018'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# 100%|██████████| 6/6 [00:11<00:00,  1.89s/it]

# %%
dataset = "KEN_Dagahaley_20170408"
city = 'dagahaley'
path_dataset = os.path.join(path_database, dataset)

convert_to_coco(path_dataset)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-777.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-778.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-779.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-780.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-781.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-782.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-783.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-784.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-785.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-786.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-787.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-788.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-789.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-790.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-791.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-792.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-793.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-794.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-795.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-796.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-797.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-798.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-799.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-800.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-801.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-802.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-803.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-804.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-805.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-806.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-807.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-808.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1-809.tif is a low contrast image
#   io.imsave(os.path.join(output_im_train, p_name), p_im)
# <ipython-input-5-11110581e3ca>:87: UserWarning: ./Data/KEN_Dagahaley_20170408/train/images/dagahaley1