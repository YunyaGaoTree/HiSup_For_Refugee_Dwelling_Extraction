# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import pathlib

print(os.getcwd())

# change the path
path = "/content/drive/MyDrive/PhD_Research/SAM/Polygonal_Mapping"
os.chdir(path)

print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content
# /content/drive/MyDrive/PhD_Research/SAM/Polygonal_Mapping

# %%
# !pip install -q imagecodecs

# import this py only after installing the package
from DataProcessing import convert_to_coco
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 37.7 MB/s eta 0:00:00

# %% [markdown]
# ## Data preparation

# %%
# print all datasets
path_database = "./data"
# os.listdir(path_database)

# %%
dataset = "Kutupalong2018_medium"
path_dataset = os.path.join(path_database, dataset)
print(path_dataset)

data_type = "train"
convert_to_coco(path_dataset, data_type)

# %%
dataset = "Kutupalong2018_medium"
path_dataset = os.path.join(path_database, dataset)
print(path_dataset)

data_type = "test"
convert_to_coco(path_dataset, data_type)

# %%
dataset = "Kutupalong2018_small"
path_dataset = os.path.join(path_database, dataset)
print(path_dataset)

data_type = "val"
convert_to_coco(path_dataset, data_type)
# Out:
# ./data/Kutupalong2018_small
# 100%|██████████| 7/7 [00:34<00:00,  4.99s/it]
